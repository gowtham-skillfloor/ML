# %% [markdown]
# # Bank Marketing - Classification

# %% [markdown]
# ## Data Import

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
  
# data (as pandas dataframes) 
X = bank_marketing.data.features 
y = bank_marketing.data.targets

# %%
type(X)
# Out:
# pandas.DataFrame

# %%
type(y)
# Out:
# pandas.DataFrame

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Combine features and target in a single dataframe
import pandas as pd

data = pd.concat([X, y], axis=1)  # Join 2 dataframes into 1
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome   y
# 0     NaN            5   may       261         1     -1         0      NaN  no
# 1     NaN            5   may       151         1     -1         0      NaN  no
# 2     NaN            5   may        76         1     -1         0      NaN  no
# 3     NaN            5   may        92         1     -1         0      NaN  no
# 4     NaN            5   may       198         1     -1         0      NaN  no

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          44923 non-null  str
#  2   marital      45211 non-null  str
#  3   education    43354 non-null  str
#  4   default      45211 non-null  str
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  str
#  7   loan         45211 non-null  str
#  8   contact      32191 non-null  str
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  str
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  poutcome     8252 non-null   str
#  16  y            45211 non-null  str
# dtypes: int64(7), str(10)
# memory usage: 7.7 MB

# %%
# Removing `poutcome` because of large amount of null values
data = data.drop(columns=['poutcome'])

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day_of_week', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'y'],
#       dtype='str')

# %%
# Replacing null values
data['job'].value_counts(normalize=True)
# Out:
# job
# blue-collar      0.216637
# management       0.210538
# technician       0.169112
# admin.           0.115108
# services         0.092469
# retired          0.050397
# self-employed    0.035149
# entrepreneur     0.033101
# unemployed       0.029005
# housemaid        0.027603
# student          0.020880
# Name: proportion, dtype: float64

# %%
data['job'].mode()
# Out:
# 0    blue-collar
# Name: job, dtype: str

# %%
data['job'].mode()[0]
# Out:
# 'blue-collar'

# %%
data['job'] = data['job'].fillna(data['job'].mode()[0])

# %%
data['job'].isnull().sum() # checking if nulls are replaced
# Out:
# np.int64(0)

# %%
data['education'] = data['education'].fillna(data['education'].mode()[0])
data['education'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['contact'] = data['contact'].fillna(data['contact'].mode()[0])
data['contact'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Checking for null values in the entire dataframe
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          45211 non-null  str
#  2   marital      45211 non-null  str
#  3   education    45211 non-null  str
#  4   default      45211 non-null  str
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  str
#  7   loan         45211 non-null  str
#  8   contact      45211 non-null  str
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  str
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  y            45211 non-null  str
# dtypes: int64(7), str(9)
# memory usage: 7.4 MB

# %%
subscr_by_age = data.groupby('y')['age'].mean()
subscr_by_age
# Out:
# y
# no     40.838986
# yes    41.670070
# Name: age, dtype: float64

# %%
subscr_by_age = subscr_by_age.reset_index()
subscr_by_age
# Out:
#      y        age
# 0   no  40.838986
# 1  yes  41.670070

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.style.use('fivethirtyeight')

# %%
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['legend.fontsize'] = 8  # Legend font size
plt.rcParams['legend.title_fontsize'] = 10  # Legend Title font size
plt.rcParams['axes.labelsize'] = 10  # X and Y-axis label size
plt.rcParams['axes.titlesize'] = 12  # Plot title size
plt.rcParams['xtick.labelsize'] = 8 # X-tick font size
plt.rcParams['ytick.labelsize'] = 8  # Y-tick font size

# %%
sns.barplot(data=subscr_by_age, 
            x='y',
            y='age')
plt.title("Term Subscription by Average Age")
# Out:
# Text(0.5, 1.0, 'Term Subscription by Average Age')

# %%
subscr_by_edu = data.groupby('y')['education'].value_counts(normalize=True).reset_index()
subscr_by_edu
# Out:
#      y  education  proportion
# 0   no  secondary    0.560017
# 1   no   tertiary    0.283177
# 2   no    primary    0.156806
# 3  yes  secondary    0.510872
# 4  yes   tertiary    0.377387
# 5  yes    primary    0.111741

# %%
sns.barplot(data=subscr_by_edu,
            x='y',
            y='proportion',
            hue='education')
# Out:
# <Axes: xlabel='y', ylabel='proportion'>

# %%
# TODO

# %% [markdown]
# ## Train-test Split

# %%
features = data.drop(columns=['y'])
target = data['y']

# %%
target.value_counts(normalize=True)
# Out:
# y
# no     0.883015
# yes    0.116985
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, 
                                                    target,
                                                    test_size=0.25,
                                                    stratify=target)
# stratify=target is to maintain target's distribution after split

# %%
X_train.shape
# Out:
# (33908, 15)

# %%
y_train.shape
# Out:
# (33908,)

# %%
y_train.value_counts(normalize=True)
# Out:
# y
# no     0.883007
# yes    0.116993
# Name: proportion, dtype: float64

# %%
X_test.shape
# Out:
# (11303, 15)

# %%
y_test.shape
# Out:
# (11303,)

# %%
y_test.value_counts(normalize=True)
# Out:
# y
# no     0.88304
# yes    0.11696
# Name: proportion, dtype: float64

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import OrdinalEncoder # for encoding categorical columns
from sklearn.preprocessing import StandardScaler, MinMaxScaler  # for scaling numerical columns
from sklearn.compose import make_column_selector as selector  # selecting column names
from sklearn.compose import ColumnTransformer  # Transform categoric and numeric columns

# %%
numeric_selector = selector(dtype_include='number')
categoric_selector = selector(dtype_include='str')

# %%
numeric_columns = numeric_selector(features)
categoric_columns = categoric_selector(features)

# %%
numeric_columns
# Out:
# ['age', 'balance', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous']

# %%
categoric_columns
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month']

# %%
preprocessor = ColumnTransformer(
    [('num', MinMaxScaler(), numeric_columns),
     ('cat', OrdinalEncoder(), categoric_columns)
    ])
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                  ['age', 'balance', 'day_of_week', 'duration',
#                                   'campaign', 'pdays', 'previous']),
#                                 ('cat', OrdinalEncoder(),
#                                  ['job', 'marital', 'education', 'default',
#                                   'housing', 'loan', 'contact', 'month'])])

# %% [markdown]
# ## Build the Model

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
lr_model = Pipeline(
    [('preprocessor', preprocessor),
     ('lr', LogisticRegression(max_iter=10000))
    ])

# %%
lr_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['age', 'balance',
#                                                    'day_of_week', 'duration',
#                                                    'campaign', 'pdays',
#                                                    'previous']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month'])])),
#                 ('lr', LogisticRegression(max_iter=10000))])

# %% [markdown]
# ## Train the Model

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search_lr = GridSearchCV(lr_model,
                               param_grid={"lr__solver": ['lbfgs', 'newton-cg', 'newton-cholesky'],
                                           },
                               scoring='balanced_accuracy')

# %%
grid_search_lr
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['age',
#                                                                           'balance',
#                                                                           'day_of_week',
#                                                                           'duration',
#                                                                           'campaign',
#                                                                           'pdays',
#                                                                           'previous']),
#                                                                         ('cat',
# ...

# %%
grid_search_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          MinMaxScaler(),
#                                                                          ['age',
#                                                                           'balance',
#                                                                           'day_of_week',
#                                                                           'duration',
#                                                                           'campaign',
#                                                                           'pdays',
#                                                                           'previous']),
#                                                                         ('cat',
# ...

# %%
dir(grid_search_lr)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_refit_for_multimetric',
#  '_check_scorers_accept_sample_weight',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_format_results',
#  '_get_class_level_metadata_request_values',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
# ...

# %%
pd.DataFrame(grid_search_lr.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.799290      0.034839         0.066021        0.007022
# 1       0.815619      0.314793         0.122103        0.042046
# 2       0.451125      0.028201         0.110511        0.022493
#
#   param_lr__solver                             params  split0_test_score  \
# 0            lbfgs            {'lr__solver': 'lbfgs'}           0.569706
# 1        newton-cg        {'lr__solver': 'newton-cg'}           0.569075
# 2  newton-cholesky  {'lr__solver': 'newton-cholesky'}           0.569075
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.583416           0.579849           0.583158           0.583242
# 1           0.583583           0.580563           0.582064           0.583242
# 2           0.583583           0.581739           0.582064           0.583242
#
#    mean_test_score  std_test_score  rank_test_score
# ...

# %%
optimal_model = grid_search_lr.best_estimator_
optimal_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   ['age', 'balance',
#                                                    'day_of_week', 'duration',
#                                                    'campaign', 'pdays',
#                                                    'previous']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month'])])),
#                 ('lr',
#                  LogisticRegression(max_iter=10000, solver='newton-cholesky'))])

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = optimal_model.predict(X_test)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score

# %%
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label='yes')
recall = recall_score(y_test, y_pred, pos_label='yes')

# %%
print("Balanced accuracy", balanced_accuracy)
print("Precision", precision)
print("Recall", recall)
# Out:
# Balanced accuracy 0.5837857814870948
# Precision 0.6211340206185567
# Recall 0.18229954614220878

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(grid_search_lr,
                                      X_test,
                                      y_test)
plt.grid(False)

# %% [markdown]
# ## How to optimize?
#
# * Instead of using all the columns, use only selected useful columns
# * Instead of using StandardScaler, use some other numeric scaler or don't scale it.
# * Instead of using OrdinalEncoder, use some other encoder.
# * Expand the range of `param_grid`
